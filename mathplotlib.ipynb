# %% [markdown]
# <a href="https://colab.research.google.com/github/VU21CSEN0100235/Python-/blob/Module-5/mathplotlib.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from matplotlib import pyplot as plt
import numpy as np
x=np.array([1,2,1])
y=np.array([5,2.5,1])
a=np.array([1,1])
b=np.array([1,5])
plt.plot(x,y,a,b)
plt.show()
